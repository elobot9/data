# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import pylab as pl

# %%
#import csvs
url_1 = 'rs_removed_part1.csv'
url_2 = 'rs_removed_part2.csv'
part_1 = pd.read_csv(url_1)
part_2 = pd.read_csv(url_2)

# %%
#remove extra column
part_1 = part_1[["ID", "composer", "condition", "name", "response_value"]]
part_2 = part_2[["ID", "composer", "condition", "name", "response_value"]]

# %%
full = part_1.append(part_1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#isolate data by question name
enjoyment = full[full["name"] == "enjoyment"]
desire = full[full["name"] == "desire-to-own"]
coherence = full[full["name"] == "coherence"]
dynamism = full[full["name"] == "dynamism"]
expressiveness = full[full["name"] == "expressiveness"]
affect = full[full["name"] == "affect"]
strangeness = full[full["name"] == "strangeness"]

# %%
#generate histograms
enjoyment_plt = enjoyment.hist(by=["composer", "condition"], sharey=True, sharex=True, bins=[0,1,2,3,4] layout=(2,3), figsize=(8,6))
pl.suptitle("Enjoyment")
plt.ylim(0, 80)
plt.xticks(np.arange(0,5, step=1))
# Out:
#   File "<ipython-input-17-e93751e0a8d6>", line 2
#     enjoyment_plt = enjoyment.hist(by=["composer", "condition"], sharey=True, sharex=True, bins=[0,1,2,3,4] layout=(2,3), figsize=(8,6))
#                                                                                                                  ^
# SyntaxError: invalid syntax

# %%
desire_plt = desire.hist(by=["composer", "condition"], sharey=True, sharex=True, layout=(2,3), bins=10, figsize=(8,6))
pl.suptitle("Desire to Own")
plt.ylim(0, 80)
plt.xticks(np.arange(0,5, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x7f1fd7532310>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
coherence_plt = coherence.hist(by=["composer", "condition"], sharey=True, sharex=True, layout=(2,3), bins=10, figsize=(8,6))
pl.suptitle("Coherence")
plt.ylim(0, 80)
plt.xticks(np.arange(0,5, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x7f1fd6eb1990>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
dynamism_plt = dynamism.hist(by=["composer", "condition"], sharey=True, sharex=True, layout=(2,3), bins=10, figsize=(8,6))
pl.suptitle("Dynamism")
plt.ylim(0, 80)
plt.xticks(np.arange(0,5, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x7f1fd6b94150>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
expressiveness_plt = expressiveness.hist(by=["composer", "condition"], sharey=True, sharex=True, layout=(2,3), bins=10, figsize=(8,6))
pl.suptitle("Expressiveness")
plt.ylim(0, 80)
plt.xticks(np.arange(0,5, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x7f1fd680af50>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
affect_plt = affect.hist(by=["composer", "condition"], sharey=True, sharex=True, layout=(2,3), bins=10, figsize=(8,6))
pl.suptitle("Affect")
plt.ylim(0, 80)
plt.xticks(np.arange(0,5, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x7f1fd6996e10>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
strangeness_plt = strangeness.hist(by=["composer", "condition"], sharey=True, sharex=True, layout=(2,3), bins=10, figsize=(8,6))
pl.suptitle("Strangeness")
plt.ylim(0, 80)
plt.xticks(np.arange(0,5, step=1))
# Out:
# ([<matplotlib.axis.XTick at 0x7f1fd6178150>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
alt_plt = full.hist(by=["name", "composer", "condition"], sharey=True, sharex=True, layout=(14, 3),figsize=(15,50), bins=10)
plt.ylim(0, 80)
# Out:
# (0, 80)
