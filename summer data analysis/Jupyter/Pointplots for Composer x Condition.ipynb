# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns

# %%
#import csvs
url_1 = 'rs_removed_part1.csv'
url_2 = 'rs_removed_part2.csv'
part_1 = pd.read_csv(url_1)
part_2 = pd.read_csv(url_2)

# %%
#remove extra column
part_1 = part_1[["ID", "composer", "condition", "name", "response_value"]]
part_2 = part_2[["ID", "composer", "condition", "name", "response_value"]]

# %%
full = part_1.append(part_1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
chopin = full[full["composer"] == "chopin"]

sns.set(style="whitegrid", palette="muted")
chopin_plt = sns.pointplot(x="name", y="response_value", hue="condition", data=chopin, hue_order=['forward', 'reversed', 'scrambled'],order=["affect", "coherence", "desire-to-own", "dynamism", "enjoyment", "expressiveness", "strangeness"], dodge=True)
chopin_plt.set_xticklabels(chopin_plt.get_xticklabels(), rotation=90)
chopin_plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
chopin_plt.set_title("Chopin ratings per question")
chopin_plt.set(ylim=(0, 4))
# Out:
# [(0, 4)]

# %%
bach = full[full["composer"] == "bach"]

sns.set(style="whitegrid", palette="muted")
bach_plt = sns.pointplot(x="name", y="response_value", hue="condition", data=bach, hue_order=['forward', 'reversed', 'scrambled'], order=["affect", "coherence", "desire-to-own", "dynamism", "enjoyment", "expressiveness", "strangeness"], dodge=True)
bach_plt.set_xticklabels(bach_plt.get_xticklabels(), rotation=90)
bach_plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
bach_plt.set_title("Bach ratings per question")
bach_plt.set(ylim=(0, 4))
# Out:
# [(0, 4)]

# %%
enjoyment = full[full["name"] == "enjoyment"]

sns.set(style="whitegrid", palette="muted")
enjoy_plot = sns.pointplot(x="condition", y="response_value", hue="composer", data=enjoyment, order=['forward', 'reversed', 'scrambled'], dodge=True)
enjoy_plot.set_xticklabels(enjoy_plot.get_xticklabels(), rotation=45)
enjoy_plot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
enjoy_plot.set_title("Enjoyment")
enjoy_plot.set(ylim=(0,4))
# Out:
# [(0, 4)]

# %%
desire = full[full["name"] == "desire-to-own"]

sns.set(style="whitegrid", palette="muted")
desire_plot = sns.pointplot(x="condition", y="response_value", hue="composer", data=desire, order=['forward', 'reversed', 'scrambled'], dodge=True)
desire_plot.set_xticklabels(desire_plot.get_xticklabels(), rotation=45)
desire_plot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
desire_plot.set_title("Desire to Own")
desire_plot.set(ylim=(0,4))
# Out:
# [(0, 4)]

# %%
coherence = full[full["name"] == "coherence"]

sns.set(style="whitegrid", palette="muted")
coherence_plot = sns.pointplot(x="condition", y="response_value", hue="composer", data=coherence, order=['forward', 'reversed', 'scrambled'], dodge=True)
coherence_plot.set_xticklabels(coherence_plot.get_xticklabels(), rotation=45)
coherence_plot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
coherence_plot.set_title("Coherence")
coherence_plot.set(ylim=(0,4))
# Out:
# [(0, 4)]

# %%
dynamism = full[full["name"] == "dynamism"]

sns.set(style="whitegrid", palette="muted")
dynamism_plot = sns.pointplot(x="condition", y="response_value", hue="composer", data=dynamism, order=['forward', 'reversed', 'scrambled'], dodge=True)
dynamism_plot.set_xticklabels(dynamism_plot.get_xticklabels(), rotation=45)
dynamism_plot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
dynamism_plot.set_title("Dynamism")
dynamism_plot.set(ylim=(0,4))
# Out:
# [(0, 4)]

# %%
expressiveness = full[full["name"] == "expressiveness"]

sns.set(style="whitegrid", palette="muted")
expressiveness_plot = sns.pointplot(x="condition", y="response_value", hue="composer", data=expressiveness, order=['forward', 'reversed', 'scrambled'], dodge=True)
expressiveness_plot.set_xticklabels(expressiveness_plot.get_xticklabels(), rotation=45)
expressiveness_plot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
expressiveness_plot.set_title("Expressiveness")
expressiveness_plot.set(ylim=(0,4))
# Out:
# [(0, 4)]

# %%
strangeness = full[full["name"] == "strangeness"]

sns.set(style="whitegrid", palette="muted")
strange_plot = sns.pointplot(x="condition", y="response_value", hue="composer", data=strangeness, order=['forward', 'reversed', 'scrambled'], dodge=True)
strange_plot.set_xticklabels(strange_plot.get_xticklabels(), rotation=45)
strange_plot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
strange_plot.set_title("Strangeness")
strange_plot.set(ylim=(0,4))
# Out:
# [(0, 4)]

# %%
affect_full = full[full["name"] == "affect"]

sns.set(style="whitegrid", palette="muted")
affect_plot = sns.pointplot(x="condition", y="response_value", hue="composer", data=affect_full, order=['forward', 'reversed', 'scrambled'], dodge=True)
affect_plot.set_xticklabels(affect_plot.get_xticklabels(), rotation=45)
affect_plot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
affect_plot.set_title("Affect (both parts)")
affect_plot.set(ylim=(0,4))
# Out:
# [(0, 4)]

# %%
affect_1 = part_1[part_1["name"] == "affect"]

sns.set(style="whitegrid", palette="muted")
affect1_plot = sns.pointplot(x="condition", y="response_value", hue="composer", data=affect_1, order=['forward', 'reversed', 'scrambled'], dodge=True)
affect1_plot.set_xticklabels(affect1_plot.get_xticklabels(), rotation=45)
affect1_plot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
affect1_plot.set_title("Affect (Part 1)")
affect1_plot.set(ylim=(0,4))
# Out:
# [(0, 4)]

# %%
affect_2 = part_2[part_2["name"] == "affect"]

sns.set(style="whitegrid", palette="muted")
affect2_plot = sns.pointplot(x="condition", y="response_value", hue="composer", data=affect_2, order=['forward', 'reversed', 'scrambled'], dodge=True)
affect2_plot.set_xticklabels(affect2_plot.get_xticklabels(), rotation=45)
affect2_plot.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
affect2_plot.set_title("Affect (Part 2)")
affect2_plot.set(ylim=(0,4))
# Out:
# [(0, 4)]
